# %%
from IPython.display import Image
import pathlib
import os

# %%
# from dotenv import load_dotenv
# load_dotenv('.env')
# robo_key = os.getenv('API_KEY')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Instalaciones y descargas necesarias

# %%
# %cd /content/drive/MyDrive/2023-1/pruebas_de_yolos
# Out:
# /content/drive/MyDrive/2023-1/pruebas_de_yolos

# %%
# %pwd
# Out:
# '/content'

# %%
# !git clone https://github.com/Luiss0606/Deteccion_de_Velocidad.git
# Out:
# Cloning into 'Deteccion_de_Velocidad'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (254/254), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 254 (delta 109), reused 223 (delta 86), pack-reused 0
# Receiving objects: 100% (254/254), 28.65 MiB | 17.69 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
# %cd Deteccion_de_Velocidad
# Out:
# [Errno 2] No such file or directory: 'Deteccion_de_Velocidad'
# /content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect

# %%
# Instalar desde la linea de comandos en al ambiente que usaras, en caso de colab solo correr el comando
# !pip install -e '.[dev]'

# %%
# %cd ultralytics
# Out:
# /content/Deteccion_de_Velocidad/ultralytics

# %%
import os

HOME = os.path.join(pathlib.Path().absolute(), "yolo", "v8", "detect")
print(HOME)

# %cd {HOME}
# Out:
# /content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect
# /content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="4c6NVylOsFaXDSrcKDsZ")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
dataset = project.version(4).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics<=8.0.20`, to intall it `pip install ultralytics<=8.0.20`.
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov8:: 100%|██████████| 48488/48488 [00:11<00:00, 4087.52it/s]

# %%
# !pip install roboflow

# from roboflow import Roboflow

# # Para 'robo_key' colocar tu api_key de roboflow
# rf = Roboflow(api_key='4c6NVylOsFaXDSrcKDsZ')
# project = rf.workspace("matheus-santos-almeida").project("car_license_plate")
# dataset = project.version(1).download("yolov8")

# %%
# %pwd
# Out:
# '/content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python train.py model=yolov8m.pt data={dataset.location}/data.yaml epochs=80 imgsz=640
# Out:
# yolo/engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect/License-Plate-Recognition-4/data.yaml, epochs=80, patience=50, batch=16, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, retina_masks=False, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, mome
# ...

# %%
# !ls /content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/runs/detect/train6
# Out:
# args.yaml					     results.csv
# events.out.tfevents.1684681118.503324c2e2dc.12086.0  train_batch0.jpg
# F1_curve.png					     train_batch1.jpg
# P_curve.png					     train_batch2.jpg
# PR_curve.png					     weights
# R_curve.png

# %%
Image(filename = '/content/Deteccion_de_Velocidad/runs/detect/train/confusion_matrix.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-347b4d026f3c> in <cell line: 1>()
# ----> 1 Image(filename = '/content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/runs/detect/train6/confusion_matrix.png')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
Image(filename = '/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/runs/detect/train7/confusion_matrix.png')

# %%
Image(filename = r'/content/Deteccion_de_Velocidad/runs/detect/train/results.png', width=600)

# %%
Image(filename = r'/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/runs/detect/train7/results.png', width=600)

# %%
Image(filename = r'/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/runs/detect/train6/val_batch1_pred.jpg', width=600)

# %%
Image(filename = r'/content/Deteccion_de_Velocidad/runs/detect/train/val_batch1_pred.jpg', width=600)

# %%
# %cd {HOME}
# Out:
# /content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=1dIyJooVaowaNUj0R1Q-HUnu-utiGsEj8&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dIyJooVaowaNUj0R1Q-HUnu-utiGsEj8&confirm=t
# To: /content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect/best.pt
# 100% 52.0M/52.0M [00:02<00:00, 23.5MB/s]

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 73.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 72.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 22.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect'

# %%
# !python val.py model='/content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/runs/detect/train6/weights/best.pt' data={dataset.location}/data.yaml
# Out:
# 2023-05-22 00:28:54.062284: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-22 00:28:55.035342: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 146MB/s]
# val: Scanning /content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect/car_license_plate-1/valid/labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
# ...

# %%
# !python val.py model={HOME}/best.pt data={dataset.location}/data.yaml
# Out:
# 2023-05-18 15:36:33.766543: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 15:36:34.790341: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect/car_license_plate-1/valid/labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.26it/s]
# ...

# %%
# !pip install easyocr

# %%
# !pwd
# Out:
# /content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=1P-oVR0J35Dw40lzw47sE19oADSW-tyb1&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1P-oVR0J35Dw40lzw47sE19oADSW-tyb1&confirm=t
# To: /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/demo.mp4
# 100% 9.56M/9.56M [00:00<00:00, 66.5MB/s]

# %%
# !python predict_.py model='/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/runs/detect/train7/weights/best.pt' source='/content/drive/MyDrive/2023-1/videoPlacas1_720.mp4'
# Out:
# python3: can't open file '/content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/ultralytics/yolo/v8/detect/predict_.py': [Errno 2] No such file or directory

# %%
# !python predict.py model={HOME}/best.pt source='/content/drive/MyDrive/2023-1/videoPlacas1_720.mp4'
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# video 1/1 (138/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.4ms
# video 1/1 (139/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.3ms
# video 1/1 (140/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.3ms
# video 1/1 (141/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.3ms
# video 1/1 (142/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.3ms
# video 1/1 (143/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.3ms
# video 1/1 (144/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 12.0ms
# video 1/1 (145/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.9ms
# video 1/1 (146/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.8ms
# video 1/1 (147/5135) /content/drive/MyDrive/2023-1/videoPlacas1_720.mp4: 384x640 11.5ms
# ...

# %% [markdown]
# # asdjasdkljansldasd

# %%
from IPython.display import HTML
from base64 import b64encode
import os

save_path = '/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/runs/detect/train17/videoPlacas1_720.mp4'
compressed_path = '/content/result_compressed.mp4'

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

mp4 = open(compressed_path,'rb').read()
data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()

# %%
HTML("""
<video width=400 controls>
  <source scr="%s" type="video/mp4">
</video>
"""% data_url)

# %% [markdown]
# # asjhdgaskjdhnashkdgbalsdnasl

# %%
# !pip install moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import moviepy.editor as mp

video = mp.VideoFileClip("/content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/runs/detect/train3/videoPlacas1_720.mp4")

# %%
from IPython.display import display

# Mostrar el video en Google Colab
video.ipython_display(width=500)
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t: 100%|█████████▉| 5133/5136 [01:39<00:00, 82.41it/s, now=None]WARNING:py.warnings:Warning: in file /content/drive/MyDrive/2023-1/pruebas_de_yolos/Deteccion_de_Velocidad/runs/detect/train3/videoPlacas1_720.mp4, 2764800 bytes wanted but 0 bytes read,at frame 5135/5136, at time 171.17/171.17 sec. Using the last valid frame instead.
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-a35809c52f00> in <cell line: 4>()
#       2
#       3 # Mostrar el video en Google Colab
# ----> 4 video.ipython_display(width=500)
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/html_tools.py in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     218         clip = clip.to_ImageClip(t)
#     219
# ...
